# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('sample dataset.xlsx')
df.head()
# Out:
#    Year Car_Model Dealership_Location  Units_Sold  Average_Price  \
# 0  2015     Sedan            New York         152       51861.72
# 1  2015     Sedan         Los Angeles         320       49279.76
# 2  2015     Sedan             Chicago         750       43874.01
# 3  2015     Sedan             Houston         171       26239.78
# 4  2015     Sedan               Miami         380       38369.96
#
#    Total_Revenue
# 0     7882981.44
# 1    15769523.20
# 2    32905507.50
# 3     4487002.38
# 4    14580584.80

# %%
revenue_by_year = df.groupby('Year')['Total_Revenue'].sum().reset_index()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))
sns.lineplot(data=revenue_by_year, x='Year', y='Total_Revenue', marker='o', color='blue')
plt.title('Total Revenue by Year (Car Dealership)', fontsize=16)
plt.xlabel('Year')
plt.ylabel('Total Revenue (USD)')
plt.xticks(revenue_by_year['Year'])
plt.tight_layout()
plt.show()
